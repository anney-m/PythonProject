# %%
from bs4 import BeautifulSoup
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt


try:
    with open('messages.html', 'r', encoding='utf-8') as file:
        html = file.read()
    soup = BeautifulSoup(html, 'html.parser')
    text = soup.get_text().lower()
    words = text.split()
    stopwords = {
        'который', 'которая', 'которые', 'которых', "жизнь", "ventus__florem", "18:45",
        "такое", "месяца", "будет", "именно", "просто",
        "недавно", "только", "november", "included,", "change", "exporting", "settings", "download.", "так", "очень", "video", "❤‍🔥",
        "знаю,", "когда", "столько", "сегодня", "потому", "немного", "april", "чтобы", "после", "каждый", "можно", "всегда",
         "может", "message", "своего", "такие", "всего", "минимум", "нужно", "больше", "чем", "быть", "вообще", "january", "march", "поэтому", "february",
        "время", "месяц", "абсолютно", "своей", "могут", "делать", "ничего", "18:40", "того,",
       "каждого", "december", "люблю", "22:07", "22:44" , "сейчас", "почему", "что-то", "человек",
        "примерно", "много", "такой", "здесь", "более", "anonymous",  "votes", "этого", "часто", "из-за",  "сколько", "никогда"
    }

    filtered_words = []
    for word in words:
        if len(word) >= 5 and word not in stopwords:
            filtered_words.append(word)

    word_counts = Counter(filtered_words)

    print("30 самых популярных слов в tg канале:")
    for word, count in word_counts.most_common(30):
        print(f"{word}: {count}")

    top_dict = dict(top_words)
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(top_dict)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title("Словесное облако 30 самых популярных слов")
    plt.show()

except Exception as e:
    print("error")
# Out:
# 30 самых популярных слов в tg канале:
# тренировки: 15
# мышцы: 14
# лучше: 9
# тренировка: 9
# тренировок: 8
# протеин: 8
# питание: 8
# мышечной: 8
# жизни: 8
# результат: 8
# хочется: 8
# получается: 7
# теперь: 7
# выглядят: 7
# выглядеть: 7
# особенно: 7
# показать: 7
# прием: 7
# белка: 7
# стоит: 7
# результаты: 7
# жиров: 7
# супер: 7
# девочки,: 7
# идеально: 7
# делаю: 7
# вариант: 7
# девушки: 7
# действительно: 6
# другой: 6
